# %% [markdown]
# <a href="https://colab.research.google.com/github/Me-gha20/SCT_DS_TaskNumber/blob/main/SCT_DS_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5767cdb5-4f0c-41a8-adc3-337898a07c23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5767cdb5-4f0c-41a8-adc3-337898a07c23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip API_SP.POP.TOTL_DS2_en_csv_v2_7.zip
# Out:
# unzip:  cannot find or open API_SP.POP.TOTL_DS2_en_csv_v2_7.zip, API_SP.POP.TOTL_DS2_en_csv_v2_7.zip.zip or API_SP.POP.TOTL_DS2_en_csv_v2_7.zip.ZIP.

# %%
# !ls
# Out:
# API_SP.POP.TOTL_DS2_en_csv_v2_40826.csv  sample_data
# API_SP.POP.TOTL_DS2_en_csv_v2_40826.zip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(
    'API_SP.POP.TOTL_DS2_en_csv_v2_7.csv',
    skiprows=4
)

data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1935264181.py in <cell line: 0>()
# ----> 1 data = pd.read_csv(
#       2     'API_SP.POP.TOTL_DS2_en_csv_v2_7.csv',
#       3     skiprows=4
#       4 )
#       5
#
# ...

# %%
data.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1253422581.py in <cell line: 0>()
# ----> 1 data.columns
#
# NameError: name 'data' is not defined

# %%
population_2022 = data[['Country Name', '2022']].dropna()
population_2022.head()
# Out:
#                   Country Name         2022
# 0                        Aruba     107310.0
# 1  Africa Eastern and Southern  731821393.0
# 2                  Afghanistan   40578842.0
# 3   Africa Western and Central  497387180.0
# 4                       Angola   35635029.0

# %%
top10 = population_2022.sort_values(by='2022', ascending=False).head(10)
top10
# Out:
#                    Country Name          2022
# 259                       World  7.989545e+09
# 103            IDA & IBRD total  6.794724e+09
# 140         Low & middle income  6.437946e+09
# 156               Middle income  5.846465e+09
# 102                   IBRD only  4.928196e+09
# 62   Early-demographic dividend  3.470645e+09
# 139         Lower middle income  3.043358e+09
# 249         Upper middle income  2.803106e+09
# 63          East Asia & Pacific  2.379617e+09
# 142   Late-demographic dividend  2.323800e+09

# %%
plt.figure(figsize=(10,5))
plt.bar(top10['Country Name'], top10['2022'])

plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Top 10 Most Populated Countries (2022)')
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(population_2022['2022'], bins=10)

plt.xlabel('Population')
plt.ylabel('Number of Countries')
plt.title('Population Distribution of Countries (2022)')

plt.show()
